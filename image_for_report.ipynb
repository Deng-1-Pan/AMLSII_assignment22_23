.50, 0.55, 0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.90, 0.95])
f2_scores_7681 = np.array([0.7751, 0.7653, 0.7550, 0.7431, 0.7293, 0.7143, 0.6983, 0.6798, 0.6587, 0.6300])
f2_scores_3841 = np.array([0.7512, 0.7413, 0.7302, 0.7177, 0.7054, 0.6906, 0.6744, 0.6567, 0.6364, 0.6093])
f2_scores_2561 = np.array([0.7511, 0.7397, 0.7271, 0.7130, 0.6991, 0.6844, 0.6684, 0.6506, 0.6286, 0.5966])
f2_scores_76810 = np.array([0.8171, 0.8089, 0.7999, 0.7896, 0.7771, 0.7621, 0.7456, 0.7254, 0.7001, 0.6650])
f2_scores_38410 = np.array([0.7966, 0.7854, 0.7742, 0.7612, 0.7466, 0.7313, 0.7142, 0.6945, 0.6714, 0.6405])
f2_scores_25610 = np.array([0.7843, 0.7720, 0.7582, 0.7430, 0.7273, 0.7105, 0.6921, 0.6728, 0.6514, 0.6221])


# Plot the bar chart
bar_width = 0.25
bar_spcae = 0.05
r1 = np.arange(len(iou_thresholds))
r2 = np.array([x + bar_width for x in r1])
r3 = np.array([x + bar_width for x in r2])
r4 = np.array([x + bar_width for x in r3])
r5 = np.array([x + bar_width for x in r4])
r6 = np.array([x + bar_width for x in r5])

plt.figure(figsize=(16, 9))

plt.bar(r1-1*bar_spcae, f2_scores_76810, color='#1E90FF', width=bar_width, edgecolor='white', label='768x768 10+5')
plt.bar(r2-0*bar_spcae, f2_scores_38410, color='#008000', width=bar_width, edgecolor='white', label='384x384 10+5')
plt.bar(r3+1*bar_spcae, f2_scores_25610, color='#800000', width=bar_width, edgecolor='white', label='256x256 10+5')
plt.bar(r1-1*bar_spcae, f2_scores_7681, color='#87CEFA', width=bar_width, edgecolor='white', label='768x768 2+1')
plt.bar(r2-0*bar_spcae, f2_scores_3841, color='#90EE90', width=bar_width, edgecolor='white', label='384x384 2+1')
plt.bar(r3+1*bar_spcae, f2_scores_2561, color='#FF6666', width=bar_width, edgecolor='white', label='256x256 2+1')


plt.xlabel('IoU threshold')
plt.ylabel('Mean F2 score')
plt.title('F2 Score based on IoU Threshold')
plt.xticks([r + bar_width for r in range(len(iou_thresholds))], iou_thresholds)
plt.legend(fontsize=8)
plt.subplots_adjust(wspace=1)

plt.grid(axis='y')

# Add a table with the same information under the graph
table_data = np.vstack((f2_scores_76810, f2_scores_38410, f2_scores_25610, f2_scores_7681, f2_scores_3841, f2_scores_2561))
row_labels = ['768x768 10+5', '384x384 10+5', '256x256 10+5', '768x768 2+1', '384x384 2+1', '256x256 2+1']
col_labels = iou_thresholds

table = plt.table(cellText=table_data,
                  rowLabels=row_labels,
                  colLabels=col_labels,
                  cellLoc='center',
                  loc='bottom',
                  bbox=[0, -0.45, 1, 0.3])

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.5)

plt.subplots_adjust(bottom=0.3)
plt.savefig('./image_for_report/F2.png', bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 12))
# Define x-axis as epoch numbers
epochs = list(range(1, 16))

x1 = range(1,16)
x2 = range(11,16)


axs[0,0].plot(epochs[:10], train_loss_768_10, color = '#87CEFA', label='768x768 freeze')
axs[0,0].plot(epochs[10:], train_loss_768_5, color = '#1E90FF', label='768x768 unfreeze')
axs[0,0].plot(epochs[10:], train_loss_384_5, color = '#90EE90',label='384x384 freeze')
axs[0,0].plot(epochs[:10], train_loss_384_10, color = '#008000',label='384x384 unfreeze')
axs[0,0].plot(epochs[:10], train_loss_256_10, color = '#FF6666',label='256x256 freeze')
axs[0,0].plot(epochs[10:], train_loss_256_5, color = '#800000',label='256x256 unfreeze')
axs[0,0].plot([1,2], train_loss_768_2, color = '#87CEFA')
# axs[0,0].scatter([3], train_loss_768, s=20, color='#1E90FF', edgecolors='black')
axs[0,0].scatter([3], train_loss_768, color = '#1E90FF')
axs[0,0].plot([1,2], train_loss_384_2, color = '#90EE90')
axs[0,0].scatter([3], train_loss_384, color = '#008000')
axs[0,0].plot([1,2], train_loss_256_2, color = '#FF6666')
axs[0,0].scatter([3], train_loss_256, color = '#800000')
axs[0,0].set_title('Train Loss')
axs[0,0].set_xlabel('Epoch')
axs[0,0].legend()
axs[0,0].set_xticks(x1)
axs[0,0].grid(True)

axs[0,1].plot(epochs[:10], valid_loss_768_10, color = '#87CEFA', label='768x768 freeze')
axs[0,1].plot(epochs[10:], valid_loss_768_5, color = '#1E90FF', label='768x768 unfreeze')
axs[0,1].plot(epochs[10:], valid_loss_384_5, color = '#90EE90',label='384x384 freeze')
axs[0,1].plot(epochs[:10], valid_loss_384_10, color = '#008000',label='384x384 unfreeze')
axs[0,1].plot(epochs[:10], valid_loss_256_10, color = '#FF6666',label='256x256 freeze')
axs[0,1].plot(epochs[10:], valid_loss_256_5, color = '#800000',label='256x256 unfreeze')
axs[0,1].plot([1,2], valid_loss_768_2, color = '#87CEFA')
axs[0,1].scatter([3], valid_loss_768, color = '#1E90FF')
axs[0,1].plot([1,2], valid_loss_384_2, color = '#90EE90')
axs[0,1].scatter([3], valid_loss_384, color = '#008000')
axs[0,1].plot([1,2], valid_loss_256_2, color = '#FF6666')
axs[0,1].scatter([3], valid_loss_256, color = '#800000')
axs[0,1].set_title('Valid Loss')
axs[0,1].set_xlabel('Epoch')
axs[0,1].legend()
axs[0,1].set_xticks(x1)
axs[0,1].grid(True)

axs[1,0].plot(epochs[:10], dice_768_10, color = '#87CEFA', label='768x768 freeze')
axs[1,0].plot(epochs[10:], dice_768_5, color = '#1E90FF', label='768x768 unfreeze')
axs[1,0].plot(epochs[10:], dice_384_5, color = '#90EE90',label='384x384 freeze')
axs[1,0].plot(epochs[:10], dice_384_10, color = '#008000',label='384x384 unfreeze')
axs[1,0].plot(epochs[:10], dice_256_10, color = '#FF6666',label='256x256 freeze')
axs[1,0].plot(epochs[10:], dice_256_5, color = '#800000',label='256x256 unfreeze')
axs[1,0].plot([1,2], dice_768_2, color = '#87CEFA')
axs[1,0].scatter([3], dice_768, color = '#1E90FF')
axs[1,0].plot([1,2], dice_384_2, color = '#90EE90')
axs[1,0].scatter([3], dice_384, color = '#008000')
axs[1,0].plot([1,2], dice_256_2, color = '#FF6666')
axs[1,0].scatter([3], dice_256, color = '#800000')
axs[1,0].set_title('Dice')
axs[1,0].set_xlabel('Epoch')
axs[1,0].legend()
axs[1,0].set_xticks(x1)
axs[1,0].grid(True)

axs[1,1].plot(epochs[:10], IoU_768_10, color = '#87CEFA', label='768x768 freeze')
axs[1,1].plot(epochs[10:], IoU_768_5, color = '#1E90FF', label='768x768 unfreeze')
axs[1,1].plot(epochs[10:], IoU_384_5, color = '#90EE90',label='384x384 freeze')
axs[1,1].plot(epochs[:10], IoU_384_10, color = '#008000',label='384x384 unfreeze')
axs[1,1].plot(epochs[:10], IoU_256_10, color = '#FF6666',label='256x256 freeze')
axs[1,1].plot(epochs[10:], IoU_256_5, color = '#800000',label='256x256 unfreeze')
axs[1,1].plot([1,2], IoU_768_2, color = '#87CEFA')
axs[1,1].scatter([3], IoU_768, color = '#1E90FF')
axs[1,1].plot([1,2], IoU_384_2, color = '#90EE90')
axs[1,1].scatter([3], IoU_384, color = '#008000')
axs[1,1].plot([1,2], IoU_256_2, color = '#FF6666')
axs[1,1].scatter([3], IoU_256, color = '#800000')
axs[1,1].set_title('IoU')
axs[1,1].set_xlabel('Epoch')
axs[1,1].legend()
axs[1,1].set_xticks(x1)
axs[1,1].grid(True)

fig.savefig('./image_for_report/metric.png', bbox_inches='tight')

# %%
# Load the images
img1 = plt.imread('./image_for_report/image_used/img25610.png')
img2 = plt.imread('./image_for_report/image_used/img38410.png')
img3 = plt.imread('./image_for_report/image_used/img76810.png')

# Create a figure with 3 axes
fig, axes = plt.subplots(3, 1, figsize=(8, 8))
plt.subplots_adjust(hspace=0.05)

# Plot each image on a separate axis
axes[0].imshow(img1)
axes[0].axis('off')
axes[1].imshow(img2)
axes[1].axis('off')
axes[2].imshow(img3)
axes[2].axis('off')

# Show the plot
fig.savefig('predict.png',bbox_inches='tight')

# %%
# Generate some random images
image1 = plt.imread('./image_for_report/image_used/0a286fb15.jpg')
image2 = plt.imread('./image_for_report/image_used/0a9883dbc.jpg')
image3 = plt.imread('./image_for_report/image_used/0a12274c2.jpg')
image4 = plt.imread('./image_for_report/image_used/0a99243c0.jpg')

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(nrows=2, ncols=2)

# Plot the images in the subplots
axes[0, 0].imshow(image1)
axes[0, 1].imshow(image2)
axes[1, 0].imshow(image3)
axes[1, 1].imshow(image4)

# Hide the x and y axis ticks for all subplots
for ax in axes.flatten():
    ax.set_xticks([])
    ax.set_yticks([])

# Show the plot
fig.subplots_adjust(hspace=0.1, wspace=0)
fig.savefig('./image_for_report/dataset.png', bbox_inches='tight')
